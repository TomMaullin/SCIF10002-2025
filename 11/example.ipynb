# %%
! mkdir src2

# %%
! touch src2/naive_script.py

# %%
! cat src2/naive_script.py
# Out:
# print("Hello, World!")

# %%
run src2/naive_script.py
# Out:
# Hello Francesco! 8

# %%
path = ! pwd

# %%
path
# Out:
# ['/Users/ft14968/Repos/intro-scientific-computing/Week11']

# %%
run src2/parabola.py
